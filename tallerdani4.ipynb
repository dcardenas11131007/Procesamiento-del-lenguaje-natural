# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
datos = pd.read_csv('C:/Users/dcard/OneDrive/Documentos/Procesamiento_del_lenguaje_Natural/dialogos (1).csv')
datos1 = datos
datos1
# Out:
#                                               Locución
# 0                                       Francamente no
# 1    Lo del canadiense. Por favor, como que vosotro...
# 2    Tienes razón. A lo mejor así te liberas de tu ...
# 3                                      Pues, tú sabrás
# 4                              Para mí que fue Krieger
# ..                                                 ...
# 954                        Yo qué sé, digo yo qué será
# 955  Lo han entendido mal. Las joyas que venden en ...
# 956                            Oooo... Me llamo Vivian
# 957                  ¿De dónde? ¿Del coño de tu madre?
# 958                       Ah, sí esto podría funcionar
#
# [959 rows x 1 columns]

# %%
datos = datos.to_string()
type(datos)
# Out:
# str

# %%
textooriginal = datos1.to_string()
textooriginal = textooriginal.strip()
#textooriginal = textooriginal.split() # Tokenizar
textooriginal
# Out:
# 'Locución\n0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Francamente no\n1                                                                                                                                                                                                                                                                                                                                                                                                                                                      
# ...

# %%
def textoRegex(quitartildes):
    a = quitartildes.replace("á", "a")
    e = a.replace("é", "e")
    i = e.replace("í", "i")
    o = i.replace("ó", "o")
    u = o.replace("ú", "u")
    return u

texto = datos.lower() # Minúscula
texto = re.sub(r"[\W\d]", " ", texto) # Dejar sólo letras
texto = textoRegex(texto)
texto = texto.strip()
#texto = texto.split() # Tokenizar
texto
# Out:
# 'locucion                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     francamente no                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...

# %%
datafc = pd.DataFrame(texto,columns=['Original'])
#Preprocesada = texto
#datafc['Preprocesada'] = Preprocesada
print(datafc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-80fe25c06774> in <module>
# ----> 1 datafc = pd.DataFrame(texto,columns=['Original'])
#       2 #Preprocesada = texto
#       3 #datafc['Preprocesada'] = Preprocesada
#       4 print(datafc)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527         else:
#     528             if index is None or columns is None:
# --> 529                 raise ValueError("DataFrame constructor not properly called!")
#     530
#     531             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %%
import nltk
nltk.download('stopwords') # Esta línea se corre sólo la primera vez

from nltk.corpus import stopwords
stopwords_sp = stopwords.words('spanish')

texto = [palabra for palabra in texto if palabra not in stopwords_sp]
texto
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dcard\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ['locucion',
#  'francamente',
#  'canadiense',
#  'favor',
#  'tirariais',
#  'alli',
#  'si',
#  'pudieseis',
#  'razon',
#  'mejor',
#  'asi',
#  'liberas',
#  'energia',
#  'nagativa',
#  'pues',
#  'sabras',
#  'krieger',
#  'bebe',
#  'lando',
#  'serio',
#  'randy',
#  'creo',
#  'deporte',
#  'hizo',
#  'daño',
#  'cerebro',
#  'estate',
#  'quieto',
#  'esperad',
#  'parecido',
#  'archer',
#  'asustado',
#  'usted',
#  'jode',
#  'carajo',
#  'dios',
#  'pibe',
#  'oigo',
#  'claro',
#  'fuma',
#  'junto',
#  'niña',
#  'decir',
#  'robotizado',
#  'coño',
#  'sacado',
#  'mano',
#  'bionica',
#  'pues',
#  'venga',
#  'subid',
#  'atras',
#  'avion',
#  'esperando',
#  'recordadme',
#  'si',
#  'desgraciado',
#  'mata',
#  'haga',
#  'jodas',
#  'cyril',
#  'haces',
#  'ventana',
#  'pues',
#  'existe',
#  'refran',
# ...
